# %% [markdown]
# ## **LINEAR ALGEBTRA**

# %% [markdown]
# # Matrix Operations:

# %%
import numpy as np
A= np.array([
    [2,-1],
    [0,3]])
B=np.array([
    [1,2],
    [-3,4]])
print("A+B=",A+B) 
print("A*B=",np.dot(A,B)) 
alpha=3
beta=2
print("3A-2B=",alpha*A-beta*B)
# Out:
# A+B= [[ 3  1]
#  [-3  7]]
# A*B= [[ 5  0]
#  [-9 12]]
# 3A-2B= [[ 4 -7]
#  [ 6  1]]

# %% [markdown]
# # Determinant and Inverse:

# %%
import numpy.linalg as LA
A= np.array([
    [2,-1],
    [0,3]])
print("determinant=",LA.det(A)) #determinant
#since determinant is not equal to zero inverse exists so,
inverse=LA.inv(A)
print("inverse of A is=",inverse)
# Out:
# determinant= 6.0
# inverse of A is= [[0.5        0.16666667]
#  [0.         0.33333333]]

# %% [markdown]
# # Eigen values and Eigen vectors:

# %%
C= np.array([
    [2,-1],
    [0,3]])
eigenvalues, eigenvectors= LA.eig(C)
print("C=",C)
print("Eigen value(first):")
print(eigenvalues[0])
print("Corresponding eigen vectors:")
print(eigenvectors[:, 0])
# Out:
# C= [[ 2 -1]
#  [ 0  3]]
# Eigen value(first):
# 2.0
# Corresponding eigen vectors:
# [1. 0.]

# %%
X=np.array([
    [4,6],
    [1.5,2.0],
    [100,150],
])
Y=np.array([ [20,30]])
print(X.T)
inv=LA.pinv(np.dot(X.T , X))
print(inv)
a=np.dot(X.T,Y)
if (Y==(np.dot(X.T,beta))):
   beta=np.dot(inv,a)
# Out:
# [[  4.    1.5 100. ]
#  [  6.    2.  150. ]]
# [[ 36.00638977 -24.00479233]
#  [-24.00479233  16.00359425]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 10
#       8 inv=LA.pinv(np.dot(X.T , X))
#       9 print(inv)
# ---> 10 a=np.dot(X.T,Y)
#      11 if (Y==(np.dot(X.T,beta))):
#      12    beta=np.dot(inv,a)
#
# ValueError: shapes (2,3) and (1,2) not aligned: 3 (dim 1) != 1 (dim 0)
